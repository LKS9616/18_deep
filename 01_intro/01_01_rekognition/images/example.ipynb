# %%
pip install base64
pip install matplotlib
#
# Out:
#   Cell In[1], line 1
#     pip install base64
#         ^
# SyntaxError: invalid syntax

# %%
import matplotlib.pyplot as plt

img = plt.imread('images/64.jpeg')

plt.imshow(img)

# %%
import base64
import boto3
import matplotlib.pyplot

rekognition = boto3.client(
    'rekognition',

    region_name='ap-northeast-2'
)
# with : 파일이 열고 닫히는 것을 자동으로 관리해주는 역할
# => 파일 작업 중에 예외가 발생해도 안전하게 닫아준다.
# rb : binary 모드로 읽겠다는 의미
with open ('images/64.jpeg', 'rb') as cf:
    
    # AWS Rekognition으로 전송하기 위해 바이너리 데이터로 전처리
    base64_image = base64.b64encode(cf.read())
    base64_binary = base64.decodebytes(base64_image)
    print("file open!")
    
response = rekognition.detect_labels(Image={'Bytes': base64_binary})

response
# Out:
# file open!
# ---------------------------------------------------------------------------
# ClientError                               Traceback (most recent call last)
# Cell In[13], line 21
#      18     base64_binary = base64.decodebytes(base64_image)
#      19     print("file open!")
# ---> 21 response = rekognition.detect_labels(Image={'Bytes': base64_binary})
#      23 response
#
# File c:\Users\80419\miniforge3\envs\pylecture_env\Lib\site-packages\botocore\client.py:569, in ClientCreator._create_api_method.<locals>._api_call(self, *args, **kwargs)
#     565     raise TypeError(
#     566         f"{py_operation_name}() only accepts keyword arguments."
#     567     )
#     568 # The "self" in this scope is referring to the BaseClient.
# --> 569 return self._make_api_call(operation_name, kwargs)
#
# File c:\Users\80419\miniforge3\envs\pylecture_env\Lib\site-packages\botocore\client.py:1023, in BaseClient._make_api_call(self, operation_name, api_params)
# ...
